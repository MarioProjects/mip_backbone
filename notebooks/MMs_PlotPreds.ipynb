# %%
# %config Completer.use_jedi = False

# %%
import os
from tqdm.notebook import tqdm
from skimage import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import albumentations
import torch

from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
sys.path.append('../')

from utils.general import *
import utils.dataload as d
from models import model_selector
from utils.data_augmentation import data_augmentation_selector
from medpy.metric.binary import hd, dc, jc, assd

from utils.neural import *
from utils.datasets import *
from utils.metrics import *

# %%
def find_path(directory, filename):
    for path in Path(directory).rglob(filename):
        return path

# %%
def save_pred(image, mask, pred_mask, case, metric_value, descriptor):
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(17, 10))
    fig.tight_layout(pad=3)  # Set spacing between plots

    ax1.imshow(image, cmap="gray")
    ax1.axis("off")
    ax1.set_title("Input Image")

    masked_lv = np.ma.masked_where(mask == 0, mask)
    ax2.imshow(image, cmap="gray")
    ax2.imshow(masked_lv, 'jet', interpolation='bilinear', alpha=0.33, vmax=3)
    ax2.axis("off")
    ax2.set_title("Ground-truth")

    masked_lv = np.ma.masked_where(pred_mask == 0, pred_mask)
    ax3.imshow(image, cmap="gray")
    ax3.imshow(masked_lv, 'jet', interpolation='bilinear', alpha=0.33, vmax=3)
    ax3.axis("off")
    ax3.set_title("Automatic Segmentation")

    fig.suptitle(f"{case} - Jaccard {metric_value:.4f}", y=0.9)
    parent_dir = os.path.join("Plots/MMs_PlotPreds", descriptor)
    os.makedirs(parent_dir, exist_ok=True)
    plt.savefig(os.path.join(parent_dir, f"{case}.jpg"), dpi=300)
    plt.close()

# %%
value_ranges = [0, 0.25, 0.5, 0.75, 1]
values_desc = ["awful", "average", "good", "excellent"]

for i in range(4):
    print(f"{value_ranges[i]} - {value_ranges[i+1]}: {values_desc[i]}")
# Out:
# 0 - 0.25: awful
# 0.25 - 0.5: average
# 0.5 - 0.75: good
# 0.75 - 1: excellent

# %%
model = model_selector(
    "segmentation", "resnet34_unet_imagenet_encoder_scse_hypercols", num_classes=4, from_swa=True,
    in_channels=3, devices=[0], checkpoint="../checks/MMs_Siemens/n1_100_swa.pt"
)

_, _, val_aug = data_augmentation_selector(
    "none", 224, 224, "padd"
)
# Out:
# --- Frosted pretrained backbone! ---
# Model total number of parameters: 35749488
# Loaded model from checkpoint: ../checks/MMs_Siemens/n1_100_swa.pt
# Using None Data Augmentation
# Padding masks!
# Padding masks!

# %%
batch_size = 1
add_depth = True
normalization = "standardize"

train_dataset = ACDC173Dataset(
    mode="full_train", transform=val_aug, img_transform=[],
    add_depth=add_depth, normalization=normalization, relative_path="../"
)

acdc_loader =  DataLoader(
    train_dataset, batch_size=batch_size, shuffle=False, pin_memory=True,
    drop_last=False, collate_fn=train_dataset.custom_collate
)

# %%
train_dataset.data
# Out:
# ['../data/AC17/training/patient051/patient051_frame01_gt.nii.gz',
#  '../data/AC17/training/patient018/patient018_frame01_gt.nii.gz',
#  '../data/AC17/training/patient015/patient015_frame01_gt.nii.gz',
#  '../data/AC17/training/patient073/patient073_frame01_gt.nii.gz',
#  '../data/AC17/training/patient042/patient042_frame01_gt.nii.gz',
#  '../data/AC17/training/patient049/patient049_frame01_gt.nii.gz',
#  '../data/AC17/training/patient069/patient069_frame12_gt.nii.gz',
#  '../data/AC17/training/patient078/patient078_frame01_gt.nii.gz',
#  '../data/AC17/training/patient012/patient012_frame13_gt.nii.gz',
#  '../data/AC17/training/patient034/patient034_frame01_gt.nii.gz',
#  '../data/AC17/training/patient035/patient035_frame11_gt.nii.gz',
#  '../data/AC17/training/patient007/patient007_frame01_gt.nii.gz',
#  '../data/AC17/training/patient003/patient003_frame15_gt.nii.gz',
#  '../data/AC17/training/patient066/patient066_frame01_gt.nii.gz',
#  '../data/AC17/training/patient077/patient077_frame01_gt.nii.gz',
#  '../data/AC17/training/patient082/patient082_frame01_gt.nii.gz',
#  '../data/AC17/training/patient029/patient029_frame12_gt.nii.gz',
#  '../data/AC17/training/patient015/patient015_frame10_gt.nii.gz',
#  '../data/AC17/training/patient091/patient091_frame01_gt.nii.gz',
#  '../data/AC17/training/patient051/patient051_frame11_gt.nii.gz',
#  '../data/AC17/training/patient023/patient023_frame09_gt.nii.gz',
#  '../data/AC17/training/patient006/patient006_frame01_gt.nii.gz',
#  '../data/AC17/training/patient020/patient020_frame11_gt.nii.gz',
#  '../data/AC17/training/patient069/patient069_frame01_gt.nii.gz',
#  '../data/AC17/training/patient013/patient013_frame14_gt.nii.gz',
#  '../data/AC17/training/patient031/patient031_frame01_gt.nii.gz',
#  '../data/AC17/training/patient017/patient017_frame01_gt.nii.gz',
#  '../data/AC17/training/patient012/patient012_frame01_gt.nii.gz',
#  '../data/AC17/training/patient046/patient046_frame01_gt.nii.gz',
#  '../data/AC17/training/patient011/patient011_frame08_gt.nii.gz',
#  '../data/AC17/training/patient021/patient021_frame13_gt.nii.gz',
#  '../data/AC17/training/patient032/patient032_frame12_gt.nii.gz',
#  '../data/AC17/training/patient047/patient047_frame01_gt.nii.gz',
#  '../data/AC17/training/patient038/patient038_frame11_gt.nii.gz',
#  '../data/AC17/training/patient038/patient038_frame01_gt.nii.gz',
#  '../data/AC17/training/patient070/patient070_frame10_gt.nii.gz',
#  '../data/AC17/training/patient037/patient037_frame01_gt.nii.gz',
#  '../data/AC17/training/patient058/patient058_frame01_gt.nii.gz',
#  '../data/AC17/training/patient056/patient056_frame01_gt.nii.gz',
#  '../data/AC17/training/patient036/patient036_frame01_gt.nii.gz',
#  '../data/AC17/training/patient076/patient076_frame01_gt.nii.gz',
#  '../data/AC17/training/patient075/patient075_frame06_gt.nii.gz',
#  '../data/AC17/training/patient044/patient044_frame01_gt.nii.gz',
#  '../data/AC17/training/patient005/patient005_frame01_gt.nii.gz',
#  '../data/AC17/training/patient026/patient026_frame01_gt.nii.gz',
#  '../data/AC17/training/patient007/patient007_frame07_gt.nii.gz',
#  '../data/AC17/training/patient080/patient080_frame01_gt.nii.gz',
#  '../data/AC17/training/patient017/patient017_frame09_gt.nii.gz',
#  '../data/AC17/training/patient042/patient042_frame16_gt.nii.gz',
#  '../data/AC17/training/patient085/patient085_frame01_gt.nii.gz',
#  '../data/AC17/training/patient071/patient071_frame01_gt.nii.gz',
#  '../data/AC17/training/patient084/patient084_frame10_gt.nii.gz',
#  '../data/AC17/training/patient082/patient082_frame07_gt.nii.gz',
#  '../data/AC17/training/patient024/patient024_frame09_gt.nii.gz',
#  '../data/AC17/training/patient014/patient014_frame13_gt.nii.gz',
#  '../data/AC17/training/patient039/patient039_frame10_gt.nii.gz',
#  '../data/AC17/training/patient040/patient040_frame13_gt.nii.gz',
#  '../data/AC17/training/patient075/patient075_frame01_gt.nii.gz',
#  '../data/AC17/training/patient049/patient049_frame11_gt.nii.gz',
#  '../data/AC17/training/patient092/patient092_frame01_gt.nii.gz',
#  '../data/AC17/training/patient081/patient081_frame01_gt.nii.gz',
#  '../data/AC17/training/patient055/patient055_frame10_gt.nii.gz',
#  '../data/AC17/training/patient061/patient061_frame10_gt.nii.gz',
#  '../data/AC17/training/patient019/patient019_frame01_gt.nii.gz',
#  '../data/AC17/training/patient006/patient006_frame16_gt.nii.gz',
#  '../data/AC17/training/patient078/patient078_frame09_gt.nii.gz',
#  '../data/AC17/training/patient086/patient086_frame08_gt.nii.gz',
#  '../data/AC17/training/patient074/patient074_frame12_gt.nii.gz',
#  '../data/AC17/training/patient022/patient022_frame01_gt.nii.gz',
#  '../data/AC17/training/patient055/patient055_frame01_gt.nii.gz',
#  '../data/AC17/training/patient025/patient025_frame01_gt.nii.gz',
#  '../data/AC17/training/patient064/patient064_frame01_gt.nii.gz',
#  '../data/AC17/training/patient041/patient041_frame11_gt.nii.gz',
#  '../data/AC17/training/patient029/patient029_frame01_gt.nii.gz',
#  '../data/AC17/training/patient033/patient033_frame01_gt.nii.gz',
#  '../data/AC17/training/patient079/patient079_frame01_gt.nii.gz',
#  '../data/AC17/training/patient004/patient004_frame01_gt.nii.gz',
#  '../data/AC17/training/patient081/patient081_frame07_gt.nii.gz',
#  '../data/AC17/training/patient068/patient068_frame12_gt.nii.gz',
#  '../data/AC17/training/patient083/patient083_frame01_gt.nii.gz',
#  '../data/AC17/training/patient100/patient100_frame13_gt.nii.gz',
#  '../data/AC17/training/patient067/patient067_frame01_gt.nii.gz',
#  '../data/AC17/training/patient062/patient062_frame09_gt.nii.gz',
#  '../data/AC17/training/patient084/patient084_frame01_gt.nii.gz',
#  '../data/AC17/training/patient045/patient045_frame13_gt.nii.gz',
#  '../data/AC17/training/patient004/patient004_frame15_gt.nii.gz',
#  '../data/AC17/training/patient063/patient063_frame01_gt.nii.gz',
#  '../data/AC17/training/patient089/patient089_frame01_gt.nii.gz',
#  '../data/AC17/training/patient043/patient043_frame07_gt.nii.gz',
#  '../data/AC17/training/patient020/patient020_frame01_gt.nii.gz',
#  '../data/AC17/training/patient071/patient071_frame09_gt.nii.gz',
#  '../data/AC17/training/patient016/patient016_frame01_gt.nii.gz',
#  '../data/AC17/training/patient030/patient030_frame12_gt.nii.gz',
#  '../data/AC17/training/patient043/patient043_frame01_gt.nii.gz',
#  '../data/AC17/training/patient099/patient099_frame09_gt.nii.gz',
#  '../data/AC17/training/patient073/patient073_frame10_gt.nii.gz',
#  '../data/AC17/training/patient047/patient047_frame09_gt.nii.gz',
#  '../data/AC17/training/patient048/patient048_frame08_gt.nii.gz',
#  '../data/AC17/training/patient097/patient097_frame01_gt.nii.gz',
#  '../data/AC17/training/patient036/patient036_frame12_gt.nii.gz',
#  '../data/AC17/training/patient059/patient059_frame01_gt.nii.gz',
#  '../data/AC17/training/patient008/patient008_frame13_gt.nii.gz',
#  '../data/AC17/training/patient067/patient067_frame10_gt.nii.gz',
#  '../data/AC17/training/patient099/patient099_frame01_gt.nii.gz',
#  '../data/AC17/training/patient050/patient050_frame01_gt.nii.gz',
#  '../data/AC17/training/patient057/patient057_frame01_gt.nii.gz',
#  '../data/AC17/training/patient064/patient064_frame12_gt.nii.gz',
#  '../data/AC17/training/patient098/patient098_frame01_gt.nii.gz',
#  '../data/AC17/training/patient001/patient001_frame01_gt.nii.gz',
#  '../data/AC17/training/patient079/patient079_frame11_gt.nii.gz',
#  '../data/AC17/training/patient027/patient027_frame01_gt.nii.gz',
#  '../data/AC17/training/patient100/patient100_frame01_gt.nii.gz',
#  '../data/AC17/training/patient060/patient060_frame01_gt.nii.gz',
#  '../data/AC17/training/patient054/patient054_frame12_gt.nii.gz',
#  '../data/AC17/training/patient025/patient025_frame09_gt.nii.gz',
#  '../data/AC17/training/patient033/patient033_frame14_gt.nii.gz',
#  '../data/AC17/training/patient066/patient066_frame11_gt.nii.gz',
#  '../data/AC17/training/patient088/patient088_frame01_gt.nii.gz',
#  '../data/AC17/training/patient021/patient021_frame01_gt.nii.gz',
#  '../data/AC17/training/patient053/patient053_frame01_gt.nii.gz',
#  '../data/AC17/training/patient059/patient059_frame09_gt.nii.gz',
#  '../data/AC17/training/patient068/patient068_frame01_gt.nii.gz',
#  '../data/AC17/training/patient096/patient096_frame08_gt.nii.gz',
#  '../data/AC17/training/patient030/patient030_frame01_gt.nii.gz',
#  '../data/AC17/training/patient094/patient094_frame07_gt.nii.gz',
#  '../data/AC17/training/patient065/patient065_frame14_gt.nii.gz',
#  '../data/AC17/training/patient040/patient040_frame01_gt.nii.gz',
#  '../data/AC17/training/patient095/patient095_frame12_gt.nii.gz',
#  '../data/AC17/training/patient032/patient032_frame01_gt.nii.gz',
#  '../data/AC17/training/patient003/patient003_frame01_gt.nii.gz',
#  '../data/AC17/training/patient014/patient014_frame01_gt.nii.gz',
#  '../data/AC17/training/patient063/patient063_frame16_gt.nii.gz',
#  '../data/AC17/training/patient041/patient041_frame01_gt.nii.gz',
#  '../data/AC17/training/patient072/patient072_frame01_gt.nii.gz',
#  '../data/AC17/training/patient085/patient085_frame09_gt.nii.gz',
#  '../data/AC17/training/patient009/patient009_frame13_gt.nii.gz',
#  '../data/AC17/training/patient086/patient086_frame01_gt.nii.gz',
#  '../data/AC17/training/patient002/patient002_frame12_gt.nii.gz',
#  '../data/AC17/training/patient035/patient035_frame01_gt.nii.gz',
#  '../data/AC17/training/patient074/patient074_frame01_gt.nii.gz',
#  '../data/AC17/training/patient098/patient098_frame09_gt.nii.gz',
#  '../data/AC17/training/patient090/patient090_frame11_gt.nii.gz',
#  '../data/AC17/training/patient077/patient077_frame09_gt.nii.gz',
#  '../data/AC17/training/patient044/patient044_frame11_gt.nii.gz',
#  '../data/AC17/training/patient054/patient054_frame01_gt.nii.gz',
#  '../data/AC17/training/patient005/patient005_frame13_gt.nii.gz',
#  '../data/AC17/training/patient018/patient018_frame10_gt.nii.gz',
#  '../data/AC17/training/patient031/patient031_frame10_gt.nii.gz',
#  '../data/AC17/training/patient076/patient076_frame12_gt.nii.gz',
#  '../data/AC17/training/patient062/patient062_frame01_gt.nii.gz',
#  '../data/AC17/training/patient024/patient024_frame01_gt.nii.gz',
#  '../data/AC17/training/patient011/patient011_frame01_gt.nii.gz',
#  '../data/AC17/training/patient060/patient060_frame14_gt.nii.gz',
#  '../data/AC17/training/patient019/patient019_frame11_gt.nii.gz',
#  '../data/AC17/training/patient010/patient010_frame01_gt.nii.gz',
#  '../data/AC17/training/patient050/patient050_frame12_gt.nii.gz',
#  '../data/AC17/training/patient034/patient034_frame16_gt.nii.gz',
#  '../data/AC17/training/patient022/patient022_frame11_gt.nii.gz',
#  '../data/AC17/training/patient097/patient097_frame11_gt.nii.gz',
#  '../data/AC17/training/patient088/patient088_frame12_gt.nii.gz',
#  '../data/AC17/training/patient045/patient045_frame01_gt.nii.gz',
#  '../data/AC17/training/patient013/patient013_frame01_gt.nii.gz',
#  '../data/AC17/training/patient083/patient083_frame08_gt.nii.gz',
#  '../data/AC17/training/patient080/patient080_frame10_gt.nii.gz',
#  '../data/AC17/training/patient037/patient037_frame12_gt.nii.gz',
#  '../data/AC17/training/patient002/patient002_frame01_gt.nii.gz',
#  '../data/AC17/training/patient052/patient052_frame09_gt.nii.gz',
#  '../data/AC17/training/patient087/patient087_frame01_gt.nii.gz',
#  '../data/AC17/training/patient027/patient027_frame11_gt.nii.gz',
#  '../data/AC17/training/patient026/patient026_frame12_gt.nii.gz',
#  '../data/AC17/training/patient009/patient009_frame01_gt.nii.gz',
#  '../data/AC17/training/patient052/patient052_frame01_gt.nii.gz',
#  '../data/AC17/training/patient053/patient053_frame12_gt.nii.gz',
#  '../data/AC17/training/patient001/patient001_frame12_gt.nii.gz',
#  '../data/AC17/training/patient048/patient048_frame01_gt.nii.gz',
#  '../data/AC17/training/patient093/patient093_frame14_gt.nii.gz',
#  '../data/AC17/training/patient065/patient065_frame01_gt.nii.gz',
#  '../data/AC17/training/patient070/patient070_frame01_gt.nii.gz',
#  '../data/AC17/training/patient056/patient056_frame12_gt.nii.gz',
#  '../data/AC17/training/patient023/patient023_frame01_gt.nii.gz',
#  '../data/AC17/training/patient094/patient094_frame01_gt.nii.gz',
#  '../data/AC17/training/patient028/patient028_frame09_gt.nii.gz',
#  '../data/AC17/training/patient028/patient028_frame01_gt.nii.gz',
#  '../data/AC17/training/patient092/patient092_frame06_gt.nii.gz',
#  '../data/AC17/training/patient096/patient096_frame01_gt.nii.gz',
#  '../data/AC17/training/patient072/patient072_frame11_gt.nii.gz',
#  '../data/AC17/training/patient008/patient008_frame01_gt.nii.gz',
#  '../data/AC17/training/patient039/patient039_frame01_gt.nii.gz',
#  '../data/AC17/training/patient010/patient010_frame13_gt.nii.gz',
#  '../data/AC17/training/patient090/patient090_frame04_gt.nii.gz',
#  '../data/AC17/training/patient057/patient057_frame09_gt.nii.gz',
#  '../data/AC17/training/patient087/patient087_frame10_gt.nii.gz',
#  '../data/AC17/training/patient095/patient095_frame01_gt.nii.gz',
#  '../data/AC17/training/patient046/patient046_frame10_gt.nii.gz',
#  '../data/AC17/training/patient061/patient061_frame01_gt.nii.gz',
#  '../data/AC17/training/patient089/patient089_frame10_gt.nii.gz',
#  '../data/AC17/training/patient091/patient091_frame09_gt.nii.gz',
#  '../data/AC17/training/patient058/patient058_frame14_gt.nii.gz',
#  '../data/AC17/training/patient093/patient093_frame01_gt.nii.gz',
#  '../data/AC17/training/patient016/patient016_frame12_gt.nii.gz']

# %%
def map_mask_classes(mask, classes_map):
    """

    Args:
        mask: (np.array) Mask Array to map (height, width)
        classes_map: (dict) Mapping between classes. E.g.  {0:0, 1:3, 2:2, 3:1 ,4:4}

    Returns: (np.array) Mapped mask array

    """
    res = np.zeros_like(mask).astype(mask.dtype)
    for value in np.unique(mask):
        if value not in classes_map:
            assert False, f"Please specify all class maps. {value} not in {classes_map}"
        res += np.where(mask == value, classes_map[value], 0).astype(mask.dtype)
    return res

# %%
model.eval()

metrics = {
    'img_id':[], 'phase':[],
    'iou_RV':[], 'dice_RV':[], 'hd_RV':[], 'assd_RV': [], 
    'iou_MYO':[], 'dice_MYO':[], 'hd_MYO':[], 'assd_MYO': [],
    'iou_LV':[], 'dice_LV':[], 'hd_LV':[], 'assd_LV': [],
}
plot_per_range = [50,50,50,50] # ["awful", "average", "good", "excellent"]
preds_dir = "CrossDatabase_v2/ACDCD2ALLMMS3D"
os.makedirs(preds_dir, exist_ok=True)

# MMS -> class_to_cat = {1: "LV", 2: "MYO", 3: "RV"}
# Original ACDC -> class_to_cat = {1: "RV", 2: "MYO", 3: "LV"}
map_classes = {0: 0, 1: 3, 2: 2, 3: 1}
class_to_cat = {1: "RV", 2: "MYO", 3: "LV"}
mask_reshape_method = "padd"
include_background = False

pred_indx=-1

with torch.no_grad():
    for batch_indx, batch in enumerate(tqdm(acdc_loader)):
        img_id = batch["img_id"][0]
        img_phase = batch["phase"][0]
        image = batch["image"].squeeze().cuda()
    
        original_masks = batch["original_mask"][0]
        original_img = batch["original_img"][0]
        
        mask_affine = batch["mask_affine"][0]
        mask_header = batch["mask_header"][0]
        
        
        prob_preds = model(image)
        pred_mask = convert_multiclass_mask(prob_preds).data.cpu().numpy()
        pred_mask = pred_mask.astype(np.uint8)
        pred_mask = map_mask_classes(pred_mask, map_classes)
        pred_mask = reshape_volume(pred_mask, original_masks.shape[-2:], mask_reshape_method)
        
        for current_class in range(len(map_classes)):

            if not include_background and current_class == 0:
                continue

            for pred_indx in range(pred_mask.shape[0]):
                
                y_true = np.where(original_masks == current_class, 1, 0).astype(np.int32)[pred_indx,...]
                y_pred = np.where(pred_mask == current_class, 1, 0).astype(np.int32)[pred_indx,...]
                class_str = class_to_cat[current_class]

                jc_score = jaccard_coef(y_true, y_pred)
                dc_score = dice_coef(y_true, y_pred)
                hd_score = secure_hd(y_true, y_pred)
                assd_score = secure_assd(y_true, y_pred)

                metrics[f'iou_{class_str}'].append(jc_score)
                metrics[f'dice_{class_str}'].append(dc_score)
                metrics[f'hd_{class_str}'].append(hd_score)
                metrics[f'assd_{class_str}'].append(assd_score)

                if jc_score <0.25:
                    if plot_per_range[0] > 0:
                        plot_per_range[0] = plot_per_range[0] - 1
                        save_pred(
                            original_img[pred_indx,...], original_masks[pred_indx,...], pred_mask[pred_indx,...], 
                            f"{img_id}_slice{pred_indx}", jc_score, values_desc[0]
                        )
                elif jc_score>0.25 and jc_score<0.5:
                    if plot_per_range[1] > 0:
                        plot_per_range[1] = plot_per_range[1] - 1
                        save_pred(
                            original_img[pred_indx,...], original_masks[pred_indx,...], pred_mask[pred_indx,...], 
                            f"{img_id}_slice{pred_indx}", jc_score, values_desc[1]
                        )
                elif jc_score>0.5 and jc_score<0.75:
                    if plot_per_range[2] > 0:
                        plot_per_range[2] = plot_per_range[2] - 1
                        save_pred(
                            original_img[pred_indx,...], original_masks[pred_indx,...], pred_mask[pred_indx,...], 
                            f"{img_id}_slice{pred_indx}", jc_score, values_desc[2]
                        )
                elif jc_score>0.75:
                    if plot_per_range[3] > 0:
                        plot_per_range[3] = plot_per_range[3] - 1
                        save_pred(
                            original_img[pred_indx,...], original_masks[pred_indx,...], pred_mask[pred_indx,...], 
                            f"{img_id}_slice{pred_indx}", jc_score, values_desc[3]
                        )
                        
            if np.array(plot_per_range).sum()==0:
                break
        if np.array(plot_per_range).sum()==0:
            break
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
df = pd.DataFrame(metrics)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-a133aaa191f2> in <module>
# ----> 1 df = pd.DataFrame(metrics)
#       2 df.head()
#
# ~/anaconda3/envs/gvenv/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/envs/gvenv/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~/anaconda3/envs/gvenv/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# ~/anaconda3/envs/gvenv/lib/python3.8/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     399             lengths = list(set(raw_lengths))
#     400             if len(lengths) > 1:
# --> 401                 raise ValueError("arrays must all be same length")
#     402
#     403             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# ## Get metrics by replacing infinite distance values with max value

# %%
print(f"Mean IOU RV: {df['iou_RV'].mean()}")
print(f"Mean IOU LV: {df['iou_LV'].mean()}")
print(f"Mean IOU MYO: {df['iou_MYO'].mean()}")

print("--------------")

print(f"Mean DICE RV: {df['dice_RV'].mean()}")
print(f"Mean DICE LV: {df['dice_LV'].mean()}")
print(f"Mean DICE MYO: {df['dice_MYO'].mean()}")

print("--------------")

print(f"Mean Hausdorff RV: {df['hd_RV'].mean()}")
print(f"Mean Hausdorff LV: {df['hd_LV'].mean()}")
print(f"Mean Hausdorff MYO: {df['hd_MYO'].mean()}")

print("--------------")

print(f"Mean ASSD RV: {df['assd_RV'].mean()}")
print(f"Mean ASSD LV: {df['assd_LV'].mean()}")
print(f"Mean ASSD MYO: {df['assd_MYO'].mean()}")

# %%
min_hausdorff_lv = df["hd_LV"].min()
print(f"min_hausdorff_lv: {min_hausdorff_lv}")
min_hausdorff_rv = df["hd_RV"].min()
print(f"min_hausdorff_rv: {min_hausdorff_rv}")
min_hausdorff_myo = df["hd_MYO"].min()
print(f"min_hausdorff_myo: {min_hausdorff_myo}")

min_assd_lv = df["assd_LV"].min()
print(f"min_assd_lv: {min_assd_lv}")
min_assd_rv = df["assd_RV"].min()
print(f"min_assd_rv: {min_assd_rv}")
min_assd_myo = df["assd_MYO"].min()
print(f"min_assd_myo: {min_assd_myo}")

# %%
max_hausdorff_lv = df["hd_LV"].max()
max_hausdorff_rv = df["hd_RV"].max()
max_hausdorff_myo = df["hd_MYO"].max()

max_assd_lv = df["assd_LV"].max()
max_assd_rv = df["assd_RV"].max()
max_assd_myo = df["assd_MYO"].max()

# %%
print(f"Mean IOU RV: {df['iou_RV'].mean()}")
print(f"Mean IOU LV: {df['iou_LV'].mean()}")
print(f"Mean IOU MYO: {df['iou_MYO'].mean()}")

print("--------------")

print(f"Mean DICE RV: {df['dice_RV'].mean()}")
print(f"Mean DICE LV: {df['dice_LV'].mean()}")
print(f"Mean DICE MYO: {df['dice_MYO'].mean()}")

print("--------------")

print(f"Mean Hausdorff RV: {df['hd_RV'].mean()}")
print(f"Mean Hausdorff LV: {df['hd_LV'].mean()}")
print(f"Mean Hausdorff MYO: {df['hd_MYO'].mean()}")

print("--------------")

print(f"Mean ASSD RV: {df['assd_RV'].mean()}")
print(f"Mean ASSD LV: {df['assd_LV'].mean()}")
print(f"Mean ASSD MYO: {df['assd_MYO'].mean()}")

# %%
df.groupby("phase").mean()

# %%
df.to_csv(os.path.join(preds_dir, "results.csv"), index=False)
