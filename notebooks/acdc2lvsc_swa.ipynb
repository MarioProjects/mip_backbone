# %%
# %config Completer.use_jedi = False

# %%
import os
from tqdm.notebook import tqdm
from skimage import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import albumentations
import torch

from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
sys.path.append('../')

from utils.general import *
import utils.dataload as d
from models import model_selector
from utils.data_augmentation import data_augmentation_selector
from medpy.metric.binary import hd, dc, jc, assd

from utils.neural import *
from utils.datasets import *
from utils.metrics import *

# %%
def find_path(directory, filename):
    for path in Path(directory).rglob(filename):
        return path

# %%
def save_pred(image, mask, pred_mask, case, metric_value, descriptor):
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(17, 10))
    fig.tight_layout(pad=3)  # Set spacing between plots

    ax1.imshow(image, cmap="gray")
    ax1.axis("off")
    ax1.set_title("Input Image")

    masked_lv = np.ma.masked_where(mask == 0, mask)
    ax2.imshow(image, cmap="gray")
    ax2.imshow(masked_lv, 'hsv', interpolation='bilinear', alpha=0.33)
    ax2.axis("off")
    ax2.set_title("Ground-truth")

    masked_lv = np.ma.masked_where(pred_mask == 0, pred_mask)
    ax3.imshow(image, cmap="gray")
    ax3.imshow(masked_lv, 'hsv', interpolation='bilinear', alpha=0.33)
    ax3.axis("off")
    ax3.set_title("Automatic Segmentation")

    fig.suptitle(f"{case} - Jaccard {metric_value:.4f}", y=0.9)
    parent_dir = os.path.join("acdc2lvsc_preds_overlays", descriptor)
    os.makedirs(parent_dir, exist_ok=True)
    plt.savefig(os.path.join(parent_dir, f"{case}.jpg"), dpi=300)
    plt.close()

# %%
value_ranges = [0, 0.25, 0.5, 0.75, 1]
values_desc = ["awful", "average", "good", "excellent"]

for i in range(4):
    print(f"{value_ranges[i]} - {value_ranges[i+1]}: {values_desc[i]}")
# Out:
# 0 - 0.25: awful
# 0.25 - 0.5: average
# 0.5 - 0.75: good
# 0.75 - 1: excellent

# %%
LV_INDEX = 2

# %%
model = model_selector(
    "segmentation", "resnet34_unet_imagenet_encoder", num_classes=4, from_swa=True,
    in_channels=3, devices=[0], checkpoint="../checks/acdc_model_resnet34_unet_imagenet_encoder_40epochs_swalr0.00256.pt"
)
# Out:
# --- Frosted pretrained backbone! ---
# Model total number of parameters: 36290058
# Loaded model from checkpoint: ../checks/acdc_model_resnet34_unet_imagenet_encoder_40epochs_swalr0.00256.pt

# %%
_, _, val_aug = data_augmentation_selector(
    "acdc172d", 224, 224, "padd"
)
# Out:
# Using LVSC 2D Segmentation Data Augmentation Combinations
# Padding masks!
# Padding masks!

# %%
batch_size = 16
add_depth = True
normalization = "standardize"

test_dataset = LVSC2Dataset(
    mode="test", transform=val_aug, img_transform=[],
    add_depth=add_depth, normalization=normalization, relative_path="../"
)

lvsc_loader =  DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True,
    drop_last=False, collate_fn=test_dataset.custom_collate
)

# %%
[item for item in test_dataset.data if "DET0000301" in item]
# Out:
# ['../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph0.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph1.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph10.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph11.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph12.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph13.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph14.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph15.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph16.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph17.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph18.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph19.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph2.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph20.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph21.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph28.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph29.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph3.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph4.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph5.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph6.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph7.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph8.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph9.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph0.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph1.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph10.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph11.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph12.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph13.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph22.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph12.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph26.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph13.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph11.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph25.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph12.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph3.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph17.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph19.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph7.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph27.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph14.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph29.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph23.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph10.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph27.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph28.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph29.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph3.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph4.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph5.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph6.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph7.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph8.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph9.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph0.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph1.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph10.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph11.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph12.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph12.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph13.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph14.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph15.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph16.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph17.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph18.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph19.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph2.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph20.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph21.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph22.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph23.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph24.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph15.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph16.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph17.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph18.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph19.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph2.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph20.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph21.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph22.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph23.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph24.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph25.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph26.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph27.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph28.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph4.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph5.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph6.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph7.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph8.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph9.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph0.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph1.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph13.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph14.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph15.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph16.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph26.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph27.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph28.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph29.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph3.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph4.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph5.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph6.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph7.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph8.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph9.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph0.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph1.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph10.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph11.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph2.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph20.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph21.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph22.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph23.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph24.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph25.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph26.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph27.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph28.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph29.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph3.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph4.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph5.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph6.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph0.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph1.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph10.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph11.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph12.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph13.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph14.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph15.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph16.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph17.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph18.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph14.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph15.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph16.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph17.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph18.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph19.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph2.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph20.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph21.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph22.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph23.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph24.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph25.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph26.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph27.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph28.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph29.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph3.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph4.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph5.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph6.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph7.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph8.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA12_ph9.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph0.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph1.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA13_ph10.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph13.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph14.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph15.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph16.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph17.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph18.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph19.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph2.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph20.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph21.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph22.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph23.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph24.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph25.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph24.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph25.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph26.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph27.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph28.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph29.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph3.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph4.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph5.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph6.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph7.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph8.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph9.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph0.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph1.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph3.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph4.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph5.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph6.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph7.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph8.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA7_ph9.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph0.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph1.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph10.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph11.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph12.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph13.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph14.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph15.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph16.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph17.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph18.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph19.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph2.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph20.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph21.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA8_ph22.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph13.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph14.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph15.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph16.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph17.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph18.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph19.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph2.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph20.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph21.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph22.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph23.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph24.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph25.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph26.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph27.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph28.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA14_ph29.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph8.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA5_ph9.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph0.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph1.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph10.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph11.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph12.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph13.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph14.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph15.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph16.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph17.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph18.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph19.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph2.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph20.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph21.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph22.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph23.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph24.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph25.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA6_ph26.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph18.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph19.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph2.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph20.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph21.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph22.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph23.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph24.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph25.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph26.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph27.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph28.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph29.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph3.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph4.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph5.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph6.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA15_ph7.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph23.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph24.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph25.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph26.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph27.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph28.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph29.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph3.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph4.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph5.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph6.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph7.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph8.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA10_ph9.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph0.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph1.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph10.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA11_ph11.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph11.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph12.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph13.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph14.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph15.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph16.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph17.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph18.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph19.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph2.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph20.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph21.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph22.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph23.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph24.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph25.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph26.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph27.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph28.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph29.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph3.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph4.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph5.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph6.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph7.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph8.dcm',
#  '../data/LVSC/Validation/CAP_challenge_validation_02/DET0000301/DET0000301_SA9_ph9.dcm']

# %%
len(test_dataset)
# Out:
# 18462

# %%
df_dict = {"patient":[], "slice":[], "phase":[]}
for path in test_dataset.data:
    path_slice = int(path[path.find("SA")+len("SA"):path.find("_ph")])
    path_phase = int(path[path.find("_ph")+len("_ph"):path.find(".dcm")])
    patient = path.split("/")[-2]
    
    df_dict["patient"].append(patient)
    df_dict["slice"].append(path_slice)
    df_dict["phase"].append(path_phase)

df_info = pd.DataFrame(df_dict)
df_info.head()

# %%
model.eval()

metrics = {'img_id':[], 'iou':[], 'dice':[], 'hd':[], 'assd': []}
plot_per_range = [0,0,0,0] # ["awful", "average", "good", "excellent"]
preds_dir = "acdc2lvsc_preds"
os.makedirs(preds_dir, exist_ok=True)

with torch.no_grad():
    for batch_indx, batch in enumerate(tqdm(lvsc_loader)):
        img_id = batch["img_id"]
        image = batch["image"].cuda()
        prob_preds = model(image)
    
        original_masks = batch["original_mask"]
        original_img = batch["original_img"]
        
        for pred_indx, single_pred in enumerate(prob_preds):
            
            path = img_id[pred_indx]
            path_slice = int(path[path.find("SA")+len("SA"):path.find("_ph")])
            path_phase = int(path[path.find("_ph")+len("_ph"):])
            path_patient = path.split("/")[0]
            middle_phase = df_info.loc[(df_info["patient"]==path_patient)]["phase"].max()//2
            current_phase = None
            
            if path_phase == 0:
                current_phase = "ED"
            elif path_phase == middle_phase:
                current_phase = "ES"
                            
            #if current_phase is None:
            #    continue
            
        
            if torch.is_tensor(original_masks[pred_indx]):
                original_mask = original_masks[pred_indx].data.cpu().numpy().astype(np.uint8).squeeze()
            else:  # numpy array
                original_mask = original_masks[pred_indx].astype(np.uint8)
            
            pred_mask = convert_multiclass_mask(single_pred.unsqueeze(0)).data.cpu().numpy()
            pred_mask = reshape_masks(pred_mask.squeeze(0), original_mask.shape, "padd")
            pred_mask = pred_mask.astype(np.uint8)
            lv_pred_mask = np.where(pred_mask==LV_INDEX, 1, 0)
        
            jc_score = jaccard_coef(lv_pred_mask, original_mask)
            dc_score = dice_coef(lv_pred_mask, original_mask)
            hd_score = secure_hd(lv_pred_mask, original_mask)
            assd_score = secure_assd(lv_pred_mask, original_mask)
            
            case = img_id[pred_indx]
            
            metrics['img_id'].append(case)
            metrics['iou'].append(jc_score)
            metrics['dice'].append(dc_score)
            metrics['hd'].append(hd_score)
            metrics['assd'].append(assd_score)
            
            """
            save_name = os.path.join(preds_dir, f"{case}.png")
            cv2.imwrite(save_name, lv_pred_mask)
            in_ = cv2.imread(save_name, cv2.IMREAD_GRAYSCALE)
            if not np.allclose(in_, lv_pred_mask):
                raise AssertionError('File read error: {:s}'.format(save_name))
            """    
            
            if jc_score <0.25:
                if plot_per_range[0] > 0:
                    plot_per_range[0] = plot_per_range[0] - 1
                    save_pred(
                        original_img[pred_indx], original_mask, lv_pred_mask, 
                        case, jc_score, values_desc[0]
                    )
            elif jc_score>0.25 and jc_score<0.5:
                if plot_per_range[1] > 0:
                    plot_per_range[1] = plot_per_range[1] - 1
                    save_pred(
                        original_img[pred_indx], original_mask, lv_pred_mask, 
                        case, jc_score, values_desc[1]
                    )
            elif jc_score>0.5 and jc_score<0.75:
                if plot_per_range[2] > 0:
                    plot_per_range[2] = plot_per_range[2] - 1
                    save_pred(
                        original_img[pred_indx], original_mask, lv_pred_mask, 
                        case, jc_score, values_desc[2]
                    )
            elif jc_score>0.75:
                if plot_per_range[3] > 0:
                    plot_per_range[3] = plot_per_range[3] - 1
                    save_pred(
                        original_img[pred_indx], original_mask, lv_pred_mask, 
                        case, jc_score, values_desc[3]
                    )
# Out:
#   0%|          | 0/1154 [00:00<?, ?it/s]

# %%
df = pd.DataFrame(metrics)
df.head()
# Out:
#                  img_id       iou      dice        hd      assd
# 0  DET0023601_SA14_ph17  0.751087  0.857852  4.123106  1.347018
# 1   DET0043801_SA9_ph20  0.740871  0.851150  5.656854  0.889112
# 2   DET0015101_SA10_ph7  0.769830  0.869948  3.605551  1.048487
# 3   DET0008001_SA8_ph15  0.704731  0.826794  5.000000  1.345523
# 4    DET0044501_SA6_ph9  0.853550  0.920990  2.828427  0.697297

# %% [markdown]
# ## Get metrics by replacing infinite distance values with max value

# %%
print(f"Mean IOU: {df['iou'].mean()}")
print(f"Mean DICE: {df['dice'].mean()}")
print(f"Mean Hausdorff: {df['hd'].mean()}")
print(f"Mean ASSD: {df['assd'].mean()}")
# Out:
# Mean IOU: 0.6827378761524501
# Mean DICE: 0.7934173178549807
# Mean Hausdorff: 6.071080533710504
# Mean ASSD: 1.6513260025628804

# %%
max_hausdorff = df["hd"].max()
max_assd = df["assd"].max()

# %%
df["hd"].replace(-1, max_hausdorff, inplace=True)
df["assd"].replace(-1, max_assd, inplace=True)

# %%
print(f"Mean IOU: {df['iou'].mean()}")
print(f"Mean DICE: {df['dice'].mean()}")
print(f"Mean Hausdorff: {df['hd'].mean()}")
print(f"Mean ASSD: {df['assd'].mean()}")
# Out:
# Mean IOU: 0.6827378761524501
# Mean DICE: 0.7934173178549807
# Mean Hausdorff: 7.619092224630712
# Mean ASSD: 2.443492124753212

# %%
df.to_csv("results.csv", index=False)
